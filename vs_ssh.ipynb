# %% [markdown]
# <a href="https://colab.research.google.com/github/toddlack/colab/blob/test/vs_ssh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setup Colab for SSH Access

# %%
# @title Colab for SSH
#setup colab_ssh
# %pip install colab_ssh --upgrade
#vscode
# %pip install -U ipykernel

from google.colab import drive, userdata
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared

#@markdown ###Global variables
repository_url='https://github.com/toddlack/colab.git' #@param{type:"string"  }
repository_branch='test' #@param{type:"string"}
repository_username='toddlack' #@param{type:"string"}
repository_email='todd.lack@gmail.com' #@param{type:"string"}
github_token_secret='github_token_todd' #@param{type:"string"}
cloudFlared_pw='testpw' #@param{type:"string"}

#connect to Google drive
drive.mount('/content/drive')

#launch ssh tunnel
launch_ssh_cloudflared(password=cloudFlared_pw,verbose=True,kill_other_processes=True)
# Optional: if you want to clone a Github or Gitlab repository
#repository_url="<PUT_YOUR_REPOSITORY_URL_HERE>"
github_token=userdata.get(github_token_secret)
print('Use this password to login:',cloudFlared_pw)
init_git_cloudflared(repository_url,
                     personal_token=github_token,
                     branch=repository_branch,
                     username=repository_username,
                     email=repository_email
                     )
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# DEBUG: Skipping cloudflared installation
# DEBUG: Skipping installation of openssh-server, package already installed
# DEBUG: Cloudflared process: PID=38294
# DEBUG: Exception: Cannot get any result from cloudflared metrics
# DEBUG: Killing 38294. Retrying...
# DEBUG: Cloudflared process: PID=38307
# DEBUG: Exception: Cannot get any result from cloudflared metrics
# DEBUG: Killing 38307. Retrying...
# DEBUG: Cloudflared process: PID=38324
# DEBUG: Exception: Cannot get any result from cloudflared metrics
# DEBUG: Killing 38324. Retrying...
# DEBUG: Cloudflared process: PID=38349
# DEBUG: {'domain': 'editions-glory-infrared-mysimon.trycloudflare.com', 'protocol': '', 'port': 22}
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# ...
